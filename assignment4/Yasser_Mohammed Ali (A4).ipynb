# %%
import pandas as pd

# %%
Lst = pd.read_csv('train.csv')

# %%
Lst
#reading the list of the titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
# Checking NaN Values for Age column
Lst[Lst.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
# Trying to assign an average age to each NaN value
avgAge = Lst.Age.mean()

# %%
avgAge
# The average age of the whole list
# Out:
# 29.69911764705882

# %%
# Replacing each NaN value in "Age" column with the average age (avgAge)
Lst.Age = Lst.Age.fillna(value= avgAge)

# %%
# Checking if this method works in replacing the NaN values or not
Lst[Lst.Age.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
# And it worked...

# %%
Survived_Elderly = Lst[Lst.Age>65][Lst.Survived==1]
# Out:
# C:\Architecture\CAD-Software\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
Survived_Elderly
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S

# %%
Unsurvived_Elderly = Lst[Lst.Age>65][Lst.Survived==0]
# Out:
# C:\Architecture\CAD-Software\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
Unsurvived_Elderly
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 33            34         0       2         Wheadon, Mr. Edward H  male  66.0
# 96            97         0       1     Goldschmidt, Mr. George B  male  71.0
# 116          117         0       3          Connors, Mr. Patrick  male  70.5
# 493          494         0       1       Artagaveytia, Mr. Ramon  male  71.0
# 672          673         0       2   Mitchell, Mr. Henry Michael  male  70.0
# 745          746         0       1  Crosby, Capt. Edward Gifford  male  70.0
# 851          852         0       3           Svensson, Mr. Johan  male  74.0
#
#      SibSp  Parch      Ticket     Fare Cabin Embarked
# 33       0      0  C.A. 24579  10.5000   NaN        S
# 96       0      0    PC 17754  34.6542    A5        C
# 116      0      0      370369   7.7500   NaN        Q
# 493      0      0    PC 17609  49.5042   NaN        C
# 672      0      0  C.A. 24580  10.5000   NaN        S
# ...

# %%
if len(Survived_Elderly)>len(Unsurvived_Elderly):
    print ('Most of the elderly people survived the catastrophe')
else:
    print ('Very few elderly people survived the catastrophe')
# Out:
# Very few elderly people survived the catastrophe

# %%
# Creating a list with people who has Dr in their names
Titles_Dr = Lst[Lst.Name.map(lambda Name: 'Dr.' in Name)]

# %%
Titles_Dr
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 245          246         0       1    Minahan, Dr. William Edward    male
# 317          318         0       2           Moraweck, Dr. Ernest    male
# 398          399         0       2               Pain, Dr. Alfred    male
# 632          633         1       1      Stahelin-Maeglin, Dr. Max    male
# 660          661         1       1  Frauenthal, Dr. Henry William    male
# 766          767         0       1      Brewe, Dr. Arthur Jackson    male
# 796          797         1       1    Leader, Dr. Alice (Farnham)  female
#
#            Age  SibSp  Parch    Ticket      Fare Cabin Embarked
# 245  44.000000      2      0     19928   90.0000   C78        Q
# 317  54.000000      0      0     29011   14.0000   NaN        S
# 398  23.000000      0      0    244278   10.5000   NaN        S
# 632  32.000000      0      0     13214   30.5000   B50        C
# ...

# %%
# Checking how many people with the title Dr survived the catastrophe
len(Titles)
# Out:
# 7

# %%
# Creating a list with people who has Mr in their names
Titles_Mr= Lst[Lst.Name.map(lambda Name: 'Mr.' in Name)]

# %%
# Checking how many people with the title Mr survived the catastrophe
Titles_Mr
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 0              1         0       3               Braund, Mr. Owen Harris
# 4              5         0       3              Allen, Mr. William Henry
# 5              6         0       3                      Moran, Mr. James
# 6              7         0       1               McCarthy, Mr. Timothy J
# 12            13         0       3        Saundercock, Mr. William Henry
# 13            14         0       3           Andersson, Mr. Anders Johan
# 17            18         1       2          Williams, Mr. Charles Eugene
# 20            21         0       2                  Fynney, Mr. Joseph J
# 21            22         1       2                 Beesley, Mr. Lawrence
# 23            24         1       1          Sloper, Mr. William Thompson
# 26            27         0       3               Emir, Mr. Farred Chehab
# 27            28         0       1        Fortune, Mr. Charles Alexander
# ...

# %%
# Checking how many people with the title Mr survived the catastrophe
len(Titles_Mr)
# Out:
# 517

# %%
# Creating a list with people who has Mrs in their names
Titles_Mrs= Lst[Lst.Name.map(lambda Name: 'Mrs.' in Name)]

# %%
Titles_Mrs
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 15            16         1       2
# 18            19         0       3
# 19            20         1       3
# 25            26         1       3
# 31            32         1       1
# 40            41         0       3
# 41            42         0       2
# 49            50         0       3
# 52            53         1       1
# 53            54         1       2
# 66            67         1       2
# 85            86         1       3
# 98            99         1       2
# 132          133         0       3
# 133          134         1       2
# 140          141         0       3
# 142          143         1       3
# 151          152         1       1
# 161          162         1       2
# 166          167         1       1
# 167          168         0       3
# ...

# %%
# Checking how many people with the title Mrs survived the catastrophe
len(Titles_Mrs)
# Out:
# 125

# %%
# Creating a list with people who has Miss in their names
Titles_Miss= Lst[Lst.Name.map(lambda Name: 'Miss.' in Name)]

# %%
# Checking how many people with the title Miss survived the catastrophe
len(Titles_Miss)
# Out:
# 182

# %%
# Trying to figure out how many people who were accompanied by their families survived
Family_Accompanied_Surv = Lst[Lst.Survived==1][Lst.SibSp + Lst.Parch > 1]
# Out:
# C:\Architecture\CAD-Software\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
Family_Accompanied_Surv
# Out:
#      PassengerId  Survived  Pclass  \
# 8              9         1       3
# 10            11         1       3
# 25            26         1       3
# 43            44         1       2
# 58            59         1       2
# 65            66         1       3
# 68            69         1       3
# 78            79         1       2
# 85            86         1       3
# 88            89         1       1
# 128          129         1       3
# 136          137         1       1
# 165          166         1       3
# 172          173         1       3
# 183          184         1       2
# 184          185         1       3
# 193          194         1       2
# 233          234         1       3
# 237          238         1       2
# 247          248         1       2
# 248          249         1       1
# 255          256         1       3
# 261          262         1       3
# 279          280         1       3
# 301          302         1       3
# ...

# %%
len(Family_Accompanied_Surv)
# Out:
# 90

# %%
len(Lst)
# Out:
# 891

# %%
# Finding the number of people who came with their family and did not survive
Family_Accompanied_NotSurv = len(Lst) - len(Family_Accompanied_Surv)

# %%
Family_Accompanied_NotSurv
# Out:
# 801

# %%
# So there were more victims among people who came with their families than those who came alone

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Trying to make sure if women and children were allowed to escape first!! Using horizontal barchart
# For males
Lst[Lst.Sex=='male'].Survived.value_counts().plot(kind='barh')

# %%
# for females
Lst[Lst.Sex=='female'].Survived.value_counts().plot(kind='barh')

# %%
# for children
Lst[Lst.Age<15].Survived.value_counts().plot(kind='barh')

# %%
# for male children
Lst[Lst.Age<15][Lst.Sex=='male'].Survived.value_counts().plot(kind='barh')
# Out:
# C:\Architecture\CAD-Software\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
# for female children
Lst[Lst.Age<15][Lst.Sex=='female'].Survived.value_counts().plot(kind='barh')
# Out:
# C:\Architecture\CAD-Software\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
# So unsurprisingly survived Women and female children were more than Men and male children
