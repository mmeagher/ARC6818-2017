# %%
import pandas as pd

# %%
df = pd.read_csv('Downloads/train.csv', header=0)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df[df.Survived==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 52            53         1       1
# 53            54         1       2
# 55            56         1       1
# ...

# %%
# %matplotlib inline

# %%
import pylab as p

# %% [markdown]
# ## What can be learned about the chances of survival from a passenger's age, cabin, class or fare?

# %%
df[df.Survived == 1]['Age'].hist(bins=16, range=(0,80))
## age:15-40 more chances of survival

# %% [markdown]
# ## Was it advantageous for survival to be a child? To be above 65?
# To be a child.

# %%
df[df.Survived == 1]['Pclass'].hist(bins=12, range=(0,3))
## pclass 1 more chances of survival

# %%
df[df.Survived == 1]['Fare'].hist(bins=30, range=(0,300))

# %%
df.sort_values(by='Cabin')[df.Survived==1]
# Out:
# C:\Users\del\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      PassengerId  Survived  Pclass  \
# 556          557         1       1
# 599          600         1       1
# 630          631         1       1
# 647          648         1       1
# 209          210         1       1
# 445          446         1       1
# 23            24         1       1
# 737          738         1       1
# 523          524         1       1
# 329          330         1       1
# 690          691         1       1
# 781          782         1       1
# 540          541         1       1
# 61            62         1       1
# 829          830         1       1
# 779          780         1       1
# 641          642         1       1
# 369          370         1       1
# 539          540         1       1
# 194          195         1       1
# ...

# %%
import numpy as np
import matplotlib.pyplot as pl

x = [df.Age]
y = [df.Survived]

pl.plot(x, y,'o')# use pylab to plot x and y
pl.show()# show the plot on the screen

# %% [markdown]
# ## Was it advantageous for survival to have been traveling with family members on the Titanic?
# YES

# %%
df['FamilySize'] = df['SibSp'] + df['Parch']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df[df.Survived == 1]['FamilySize'].hist(bins=8, range=(0,8))

# %%
df[df.Survived == 0]['FamilySize'].hist(bins=10, range=(0,10))

# %% [markdown]
# ## Which passenger attributes give the a good prediction of survival? Provide evidence to support your conclusion.
# •	Compared with these two diagrams, we can find Pclass、FamilySize and Fare are important influences to survivals. Passenger who are in Pclass 3 have less opportunities to survive. On the contrast, survivals who are in Pclass 1 can be saved. Passenger traveled with their parents and siblings have a high ratio to be survive. When passenger spent less money on fare, they have less opportunities to survive.

# %%
df[df.Survived ==0].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000003866C3ACC0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000003866FB1A58>]], dtype=object)

# %%
df[df.Survived ==1].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000003867026E48>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000003868530BA8>]], dtype=object)

# %% [markdown]
# ## Can anything be learned  from the names of the passengers that is relevant for understanding survival?
# According to alphabetical order, It is more opportunities for passengers whose name is beginning from A to survive.

# %%
df.sort_values(by='Name')[df.Survived==1]
# Out:
# C:\Users\del\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      PassengerId  Survived  Pclass  \
# 279          280         1       3
# 874          875         1       2
# 855          856         1       3
# 207          208         1       3
# 730          731         1       1
# 305          306         1       1
# 192          193         1       3
# 460          461         1       1
# 68            69         1       3
# 146          147         1       3
# 275          276         1       1
# 518          519         1       2
# 571          572         1       1
# 261          262         1       3
# 233          234         1       3
# 25            26         1       3
# 700          701         1       1
# 369          370         1       1
# 780          781         1       3
# 85            86         1       3
# ...

# %%
df.sort_values(by='Name')[df.Survived==0]
# Out:
# C:\Users\del\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      PassengerId  Survived  Pclass  \
# 845          846         0       3
# 746          747         0       3
# 308          309         0       2
# 365          366         0       3
# 401          402         0       3
# 40            41         0       3
# 810          811         0       3
# 840          841         0       3
# 210          211         0       3
# 784          785         0       3
# 4              5         0       3
# 297          298         0       1
# 498          499         0       1
# 834          835         0       3
# 850          851         0       3
# 813          814         0       3
# 119          120         0       3
# 541          542         0       3
# 542          543         0       3
# 13            14         0       3
# ...
