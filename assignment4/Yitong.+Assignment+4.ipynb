# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

df = pd.read_csv('train.csv',header=0)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df['Name_lengeh']=df.Name.apply(len)
sns.factorplot(x='Sex', y='Name_lengeh', col='Pclass',hue='Survived', data=df, kind='swarm')
plt.show()

# %%
#This part shows the relationship between the length of name and the survival rate of 2 genders in 3 Pclasses.

# %% [markdown]
# FamilySize

# %%
SS = pd.DataFrame()
fig = plt.figure()
ax = fig.add_subplot(111)


df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
SS['PassengerNum'] = df[['FamilySize','Survived']].groupby(['FamilySize'])['Survived'].count()
SS['FamSize'] = SS.index.values
SS['Survived'] = df[['FamilySize','Survived']].groupby(['FamilySize'])['Survived'].sum()
SS['Ratio'] = SS.Survived / SS.PassengerNum * 100

pd.crosstab(df["FamilySize"],df["Survived"]).plot(kind="line")
SS.Ratio.plot(kind='bar', color='red', ax=ax, label = 'Ratio')
ax.set_ylabel('%')
ax.legend(['Ratio'])
plt.show()

# %%
#The FamilySize under 4 has the higher death rate.As those which have more than 4 have lower death rate.

# %% [markdown]
# Embarked

# %%
sns.factorplot('Embarked','Survived', data=df,size=2,aspect=4)    

plt.show()

# %%
#In Embarked C has the higher rate of survival

# %% [markdown]
# Age & Fare & Pclass

# %%
fig, ax = plt.subplots()

ylive = df.Fare[df.Survived==1]
ydie = df.Fare[df.Survived==0]
xlive = df.Age[df.Survived==1]
xdie = df.Age[df.Survived==0]

m = ax.scatter(xlive, ylive, 5, 'pink')
ax.hold
n = ax.scatter(xdie, ydie, 5, 'red')
ax.hold

ax.set_xlabel('Age')
ax.set_ylabel('Fare')

ax.legend([m,n],['Survived','Died'])

plt.show()

# %%
#This part is describe the figure for age and fare without the restriction of Pclass.From this part,it is clear to see that the price of tickets are focus on 0-100,the passengers' mostly from 15-50.And the dead rate is concentrite on this part,especially in 20-to-50 people.

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Age group')
ax.set_ylabel('Fare group')
ax.set_zlabel('Pclass group')

a = df['Pclass']

for z1 in a:
    xlive= df.Age[(df.Survived==1) & (df.Pclass==z1)]
    ylive= df.Fare[(df.Survived==1) & (df.Pclass==z1)]
    ax.scatter(xlive, ylive, z1, zdir='z', color='pink',alpha=0.6)

for z2 in a:
    xdie= df.Age[(df.Survived==0) & (df.Pclass==z2)]
    ydie= df.Fare[(df.Survived==0) & (df.Pclass==z2)]
    ax.scatter(xdie, ydie, z2, zdir='z', color='red',alpha=0.6)

plt.show()

# %%
#This part is describe figures for the relationship between age and fare in 3 Pclasses.

# %% [markdown]
# Sex&Death

# %%
Man=df[df.Sex=='male']
Man['Age'][Man.Survived==0].hist(bins=100,range=(0,80))
plt.show()

# %%
Fe=df[df.Sex=='female']
Fe['Age'][Fe.Survived==0].hist(bins=100,range=(0,80))
plt.show()

# %%
#From the gragh,it's easy to see the number of female dead in this accident is lower the that of male.

# %% [markdown]
# Younth&Old

# %%
ax = sns.pointplot(x="Age", y="Survived", data=df[df.Age>65],color='r')
plt.show()
ax = sns.pointplot(x="Age", y="Survived", data=df[df.Age<15],color='pink')
plt.show()

# %%
#From these part, the death rate of the old who over 65 have almost 100 percent.And that of the younth is much higher.

# %% [markdown]
# Conclusion
#
# The young and female have higher survival rate than male and old.And the higher class passengers have the lower death rate they will have.And the embarked C has the highest survival rate among all embarkation.Both male and famel,the shorter length of name has more higher survival rate than those who has the longer one.
