# %% [markdown]
# # FIFA 18 players analysis

# %%
import pandas as pd

# %%
FF = pd.read_csv("FIFA 18 CompleteDataset.csv")
# Out:
# C:\Architecture\CAD-Software\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (23,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
FF
# Out:
#        Unnamed: 0               Name  Age  \
# 0               0  Cristiano Ronaldo   32
# 1               1           L. Messi   30
# 2               2             Neymar   25
# 3               3          L. Suárez   30
# 4               4           M. Neuer   31
# 5               5     R. Lewandowski   28
# 6               6             De Gea   26
# 7               7          E. Hazard   26
# 8               8           T. Kroos   27
# 9               9         G. Higuaín   29
# 10             10       Sergio Ramos   31
# 11             11       K. De Bruyne   26
# 12             12        T. Courtois   25
# 13             13         A. Sánchez   28
# 14             14          L. Modrić   31
# 15             15            G. Bale   27
# 16             16          S. Agüero   29
# 17             17       G. Chiellini   32
# 18             18          G. Buffon   39
# 19             19          P. Dybala   23
# 20             20           J. Oblak   24
# ...

# %%
FF.describe()

# Taking a rough idea of the overall table
# Out:
#          Unnamed: 0           Age       Overall     Potential       Special  \
# count  17981.000000  17981.000000  17981.000000  17981.000000  17981.000000
# mean    8990.000000     25.144541     66.247984     71.190813   1594.095100
# std     5190.811931      4.614272      6.987965      6.102199    272.151435
# min        0.000000     16.000000     46.000000     46.000000    728.000000
# 25%     4495.000000     21.000000     62.000000     67.000000   1449.000000
# 50%     8990.000000     25.000000     66.000000     71.000000   1633.000000
# 75%    13485.000000     28.000000     71.000000     75.000000   1786.000000
# max    17980.000000     47.000000     94.000000     94.000000   2291.000000
#
#                 CAM            CB           CDM            CF            CM  \
# count  15952.000000  15952.000000  15952.000000  15952.000000  15952.000000
# mean      59.251755     55.550464     56.865283     59.030028     58.506833
# ...

# %%
FF = FF.drop('Unnamed: 0', axis =1)

# Deleting the "Unamed 0" column from the table

# %%
FF.columns
# Out:
# Index(['Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall', 'Potential',
#        'Club', 'Club Logo', 'Value', 'Wage', 'Special', 'Acceleration',
#        'Aggression', 'Agility', 'Balance', 'Ball control', 'Composure',
#        'Crossing', 'Curve', 'Dribbling', 'Finishing', 'Free kick accuracy',
#        'GK diving', 'GK handling', 'GK kicking', 'GK positioning',
#        'GK reflexes', 'Heading accuracy', 'Interceptions', 'Jumping',
#        'Long passing', 'Long shots', 'Marking', 'Penalties', 'Positioning',
#        'Reactions', 'Short passing', 'Shot power', 'Sliding tackle',
#        'Sprint speed', 'Stamina', 'Standing tackle', 'Strength', 'Vision',
#        'Volleys', 'CAM', 'CB', 'CDM', 'CF', 'CM', 'ID', 'LAM', 'LB', 'LCB',
#        'LCM', 'LDM', 'LF', 'LM', 'LS', 'LW', 'LWB', 'Preferred Positions',
#        'RAM', 'RB', 'RCB', 'RCM', 'RDM', 'RF', 'RM', 'RS', 'RW', 'RWB', 'ST'],
#       dtype='object')

# %%
print(FF.shape)
# Out:
# (17981, 74)

# %%
FF.head(10)
# Out:
#                 Name  Age                                            Photo  \
# 0  Cristiano Ronaldo   32   https://cdn.sofifa.org/48/18/players/20801.png
# 1           L. Messi   30  https://cdn.sofifa.org/48/18/players/158023.png
# 2             Neymar   25  https://cdn.sofifa.org/48/18/players/190871.png
# 3          L. Suárez   30  https://cdn.sofifa.org/48/18/players/176580.png
# 4           M. Neuer   31  https://cdn.sofifa.org/48/18/players/167495.png
# 5     R. Lewandowski   28  https://cdn.sofifa.org/48/18/players/188545.png
# 6             De Gea   26  https://cdn.sofifa.org/48/18/players/193080.png
# 7          E. Hazard   26  https://cdn.sofifa.org/48/18/players/183277.png
# 8           T. Kroos   27  https://cdn.sofifa.org/48/18/players/182521.png
# 9         G. Higuaín   29  https://cdn.sofifa.org/48/18/players/167664.png
#
#   Nationality                                 Flag  Overall  Potential  \
# ...

# %%
footbplrs = FF[['Name', 'Age', 'Club', 'Overall']]

# %%
footbplrs.isnull().head(10)

# Getting rid of the NaN values
# Out:
#     Name    Age   Club  Overall
# 0  False  False  False    False
# 1  False  False  False    False
# 2  False  False  False    False
# 3  False  False  False    False
# 4  False  False  False    False
# 5  False  False  False    False
# 6  False  False  False    False
# 7  False  False  False    False
# 8  False  False  False    False
# 9  False  False  False    False

# %%
footbplrs.isnull().sum()
# Out:
# Name         0
# Age          0
# Club       248
# Overall      0
# dtype: int64

# %%
footbplrs = footbplrs.dropna()

# %%
footbplrs.sort_values('Age').head(20)

# Listing players from the oldest to the youngest player
# Out:
#                 Name  Age                   Club  Overall
# 10556      K. Pierie   16          SC Heerenveen       65
# 15119  L. Geertruida   16              Feyenoord       59
# 15571   Javi Vázquez   16       Sevilla Atlético       58
# 17667        J. Hove   16                Sogndal       51
# 15968      E. Håland   16               Molde FK       58
# 11397       A. Gomes   16      Manchester United       64
# 17014    R. Strechie   16  F.B.C. Unione Venezia       54
# 16116      M. Sprang   16            FSV Zwickau       57
# 13733     E. Vignato   16          Chievo Verona       61
# 15837      J. Romero   16       Atlético Tucumán       58
# 15063   G. McEachran   16                Chelsea       59
# 17055     V. Barbero   16    Belgrano de Córdoba       54
# 17025      L. Pintor   16      Stade Brestois 29       54
# 16988       N. Perry   17              AIK Solna       54
# 16809       P. Vagic   17               Malmö FF       55
# ...

# %%
footbplrs.sort_values('Age', ascending=False).head(20)

# Listing players from oldest to youngest player
# Out:
#                 Name  Age                       Club  Overall
# 17977  B. Richardson   47          Wycombe Wanderers       46
# 4839        O. Pérez   44                    Pachuca       71
# 5314    E. El Hadary   44                 Al Taawoun       70
# 16834      J. Walker   43               Lincoln City       55
# 16696       D. Coyne   43                 Shrewsbury       55
# 16121         C. Day   41                  Stevenage       57
# 6654            Quim   41                    CD Aves       69
# 7727       K. Wæhler   41                    Sogndal       67
# 13863       M. Brown   40                  Port Vale       61
# 2224        B. Nivet   40               ES Troyes AC       74
# 3309      M. Candelo   40  Asociacion Deportivo Cali       72
# 3148       T. Simons   40             Club Brugge KV       73
# 1408      M. Storari   40                      Milan       76
# 16584       W. Brown   40              Oxford United       56
# ...

# %%
footbplrs.groupby('Club').mean().sort_values('Age')

# Finding out the average players age for each club
# Out:
#                                          Age    Overall
# Club
# Sevilla Atlético                   19.793103  64.965517
# FC Barcelona B                     20.379310  66.689655
# Werder Bremen II                   21.400000  60.240000
# LOSC Lille                         21.629630  69.037037
# Crewe Alexandra                    21.884615  56.307692
# FC Nordsjælland                    22.000000  60.888889
# Galway United                      22.040000  54.040000
# Ajax                               22.068966  73.241379
# Barnsley                           22.100000  62.533333
# PSV                                22.115385  71.615385
# Walsall                            22.142857  61.321429
# Stabæk Fotball                     22.148148  61.296296
# Envigado FC                        22.214286  60.785714
# KRC Genk                           22.275862  69.000000
# Olympique Lyonnais                 22.323529  70.705882
# NAC Breda                          22.366667  63.933333
# ...

# %%
RealMadrid_footbplrs = footbplrs[footbplrs['Club'] == 'Real Madrid CF']

# Extracting Real Madrid (my favourite team) players from the whole list

# %%
RealMadrid_footbplrs.sort_values('Age', ascending=False)

# Sorting Real Madrid players gradually by age (from oldest to youngest)
# Out:
#                     Name  Age            Club  Overall
# 0      Cristiano Ronaldo   32  Real Madrid CF       94
# 10          Sergio Ramos   31  Real Madrid CF       90
# 14             L. Modrić   31  Real Madrid CF       89
# 74              K. Navas   30  Real Madrid CF       85
# 467         Kiko Casilla   30  Real Madrid CF       80
# 39               Marcelo   29  Real Madrid CF       87
# 64            K. Benzema   29  Real Madrid CF       86
# 15               G. Bale   27  Real Madrid CF       89
# 326      Nacho Fernández   27  Real Madrid CF       81
# 8               T. Kroos   27  Real Madrid CF       90
# 213        Lucas Vázquez   26  Real Madrid CF       82
# 98              Carvajal   25  Real Madrid CF       84
# 71              Casemiro   25  Real Madrid CF       85
# 48                  Isco   25  Real Madrid CF       86
# 70             R. Varane   24  Real Madrid CF       85
# 218           M. Kovačić   23  Real Madrid CF       82
# ...

# %%
footbplrs= FF[['Name', 'Age', 'Club', 'Overall', 'Wage']].dropna()

# %%
footbplrs.head(10)
# Out:
#                 Name  Age                 Club  Overall   Wage
# 0  Cristiano Ronaldo   32       Real Madrid CF       94  €565K
# 1           L. Messi   30         FC Barcelona       93  €565K
# 2             Neymar   25  Paris Saint-Germain       92  €280K
# 3          L. Suárez   30         FC Barcelona       92  €510K
# 4           M. Neuer   31     FC Bayern Munich       92  €230K
# 5     R. Lewandowski   28     FC Bayern Munich       91  €355K
# 6             De Gea   26    Manchester United       90  €215K
# 7          E. Hazard   26              Chelsea       90  €295K
# 8           T. Kroos   27       Real Madrid CF       90  €340K
# 9         G. Higuaín   29             Juventus       90  €275K

# %%
footbplrs.dtypes

# Checking the value type of "Wage" so we can list them in an ascending or descending order
# Out:
# Name       object
# Age         int64
# Club       object
# Overall     int64
# Wage       object
# dtype: object

# %%
wages = footbplrs['Wage'].map(lambda x: x.replace('€', ''))

# Getting rid of the "€" symbol in the "Wage" column

# %%
wages.head()
# Out:
# 0    565K
# 1    565K
# 2    280K
# 3    510K
# 4    230K
# Name: Wage, dtype: object

# %%
wages = wages.map(lambda x: x.replace('K', ''))

# Getting rid of the "€" symbol in the "Wage" column

# %%
wages = wages.astype('int')*1000

# Multiplying each "Wage" value by 1000 instead of the letter "K"

# %%
footbplrs.loc[:, 'Wage'] = wages.values

# Assigning the new values to the "Wage" column

# %%
footbplrs.dtypes

# And Wage values are now converted from "object" to "integer"
# Out:
# Name       object
# Age         int64
# Club       object
# Overall     int64
# Wage        int32
# dtype: object

# %%
footbplrs.groupby('Club')['Wage'].mean().sort_values(ascending= False).head(10)

# Finding out which team spends most on his players on average
# Out:
# Club
# FC Barcelona           191680.000000
# Real Madrid CF         182730.769231
# FC Bayern Munich       125884.615385
# Juventus               121730.769231
# Manchester United      107441.176471
# Chelsea                107181.818182
# Manchester City         95515.151515
# Arsenal                 91121.212121
# Liverpool               83250.000000
# Paris Saint-Germain     78500.000000
# Name: Wage, dtype: float64

# %%
footbplrs.groupby('Club').mean().sort_values('Wage', ascending = False).head(10)

# Finding out the exact Wage each team players receive from their teams, in a descending order
# Out:
#                            Age    Overall           Wage
# Club
# FC Barcelona         26.520000  82.560000  191680.000000
# Real Madrid CF       24.576923  81.038462  182730.769231
# FC Bayern Munich     25.076923  79.423077  125884.615385
# Juventus             27.769231  81.653846  121730.769231
# Manchester United    24.617647  77.705882  107441.176471
# Chelsea              24.363636  76.666667  107181.818182
# Manchester City      23.454545  74.121212   95515.151515
# Arsenal              24.727273  75.757576   91121.212121
# Liverpool            23.875000  75.875000   83250.000000
# Paris Saint-Germain  24.392857  77.964286   78500.000000

# %%
footbplrs.sort_values('Wage', ascending = False).head(20)

# Listing players from the one with the highest wage to the lowest wage
# Out:
#                  Name  Age                 Club  Overall    Wage
# 0   Cristiano Ronaldo   32       Real Madrid CF       94  565000
# 1            L. Messi   30         FC Barcelona       93  565000
# 3           L. Suárez   30         FC Barcelona       92  510000
# 15            G. Bale   27       Real Madrid CF       89  370000
# 5      R. Lewandowski   28     FC Bayern Munich       91  355000
# 14          L. Modrić   31       Real Madrid CF       89  340000
# 8            T. Kroos   27       Real Madrid CF       90  340000
# 16          S. Agüero   29      Manchester City       89  325000
# 10       Sergio Ramos   31       Real Madrid CF       90  310000
# 64         K. Benzema   29       Real Madrid CF       86  295000
# 7           E. Hazard   26              Chelsea       90  295000
# 11       K. De Bruyne   26      Manchester City       89  285000
# 2              Neymar   25  Paris Saint-Germain       92  280000
# ...

# %%
footbplrs = FF [['Name', 'Age', 'Club', 'Overall', 'Nationality']].dropna()

# %%
% matplotlib inline

# %%
footbplrs.groupby('Nationality').Name.count().sort_values(ascending= False).head(10).plot(kind='barh')

# to know how many players each country has in FIFA 18 in a horizontal bar chart

# %%
footbplrs.groupby('Nationality').Name.count()

# to know how many players each country has in FIFA 18
# Out:
# Nationality
# Afghanistan                3
# Albania                   35
# Algeria                   57
# Angola                    15
# Antigua & Barbuda          5
# Argentina                965
# Armenia                   14
# Australia                224
# Austria                  266
# Azerbaijan                 7
# Barbados                   1
# Belarus                    9
# Belgium                  271
# Belize                     1
# Benin                     14
# Bermuda                    4
# Bolivia                    2
# Bosnia Herzegovina        55
# Brazil                   809
# Brunei Darussalam          1
# Bulgaria                  20
# Burkina Faso              14
# Burundi                    1
# Cameroon                  80
# Canada                    50
# Cape Verde                22
# Central African Rep.       4
# Chad                       2
# Chile                    368
# China PR                   4
#                         ...
# ...

# %%
footbplrs.groupby('Nationality').Name.count().sort_values(ascending = False).head(10)

# to know how many players each country has in FIFA 18 but now in a descending order
# Out:
# Nationality
# England        1630
# Germany        1140
# Spain          1019
# France          978
# Argentina       965
# Brazil          809
# Italy           799
# Colombia        591
# Japan           469
# Netherlands     429
# Name: Name, dtype: int64

# %%
footbplrs.groupby('Nationality').Name.count().sort_values(ascending = False).head(10).plot(kind = 'pie')

# # to know how many players each country has in FIFA 18 using pie chart
