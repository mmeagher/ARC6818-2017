# %% [markdown]
# ## Natural Language Toolkit (NLTK) Intro

# %% [markdown]
# *sources for this workshop*

# %% [markdown]
# [O'Reilly 'Natural Language Processing with Python' Book (Chapters 1 and 3)](http://www.nltk.org/book/)

# %% [markdown]
# [Kaggle: NLP for Beginners - Bag of Words](https://www.kaggle.com/c/word2vec-nlp-tutorial/details/part-1-for-beginners-bag-of-words)

# %% [markdown]
# [Stack Overflow: 'Plotting Words Frequency and NLTK'](http://stackoverflow.com/questions/29755861/plotting-words-frequency-and-nltk)

# %% [markdown]
# *first import the necessary modules*

# %%
import nltk, re, pprint

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
nltk.data.path.append("C:/nltk_data/")

# %% [markdown]
# *and the sample texts*

# %%
from nltk.book import *

# %% [markdown]
# *check out the attributes of the texts*

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
len(text4)
# Out:
# 145735

# %%
sorted(set(text4))
# Out:
# ['!',
#  '"',
#  '";',
#  '"?',
#  '$',
#  "'",
#  '(',
#  ')',
#  '),',
#  ',',
#  ',"',
#  '-',
#  '--',
#  '.',
#  '."',
#  '.)',
#  '...',
#  '....',
#  '.¡¨',
#  '000',
#  '1',
#  '100',
#  '120',
#  '125',
#  '13',
#  '14th',
#  '15th',
#  '16',
#  '1774',
#  '1776',
#  '1778',
#  '1780',
#  '1787',
#  '1789',
#  '1790',
#  '1800',
#  '1801',
#  '1812',
#  '1815',
#  '1816',
#  '1817',
#  '1818',
#  '1826',
#  '1850',
#  '1861',
#  '1868',
#  '1873',
#  '1880',
#  '1886',
#  '1890',
#  '1893',
#  '1896',
#  '1897',
#  '1898',
#  '1899',
#  '18th',
#  '1907',
#  '1917',
#  '1933',
#  '1941',
#  '1945',
#  '1963',
#  '1972',
#  '1980',
#  '1984',
#  '19th',
#  '2',
#  '20',
#  '200',
#  '200th',
#  '20th',
#  '21st',
#  '225',
#  '25',
#  '3',
#  '30',
#  '30th',
#  '3d',
#  '4',
#  '41',
#  '48',
#  '4th',
#  '5',
#  '50',
#  '50th',
#  '6',
#  '60',
#  '67',
#  '6th',
#  '7',
#  '8',
#  '9',
#  ':',
#  ';',
#  '?',
#  '?"',
#  'A',
#  'AIDS',
#  'ALL',
#  'AMENDMENT',
#  'AS',
#  'Abandonment',
#  'Abhorring',
#  'About',
#  'Above',
#  'Abraham',
#  'Abroad',
#  'Accept',
#  'Across',
#  'Act',
#  'Acting',
#  'Action',
#  'Actual',
#  'Adams',
#  'Additional',
#  'Address',
#  'Administered',
#  'Administration',
#  'Administrations',
#  'Advance',
#  'Advancing',
#  'Afghanistan',
#  'Africa',
#  'African',
#  'After',
#  'Again',
#  'Age',
#  'Agriculture',
#  'Alamo',
#  'All',
#  'Alleghanies',
#  'Almighty',
#  'Almost',
#  'Along',
#  'Already',
#  'Although',
#  'Always',
#  'Amelia',
#  'Amen',
#  'America',
#  'American',
#  'Americanism',
#  'Americans',
#  'Americas',
#  'Amid',
#  'Amidst',
#  'Among',
#  'Amongst',
#  'An',
#  'And',
#  'Andes',
#  'Annihilate',
#  'Another',
#  'Anthony',
#  'Anxiety',
#  'Anxious',
#  'Any',
#  'Anyone',
#  'Apollo',
#  'Appreciating',
#  'Apprehension',
#  'April',
#  'Arbitration',
#  'Archibald',
#  'Are',
#  'Argonne',
#  'Arlington',
#  'Armies',
#  'Army',
#  'Articles',
#  'As',
#  'Asia',
#  'Asiatic',
#  'Assessing',
#  'Assistance',
#  'Association',
#  'Assuring',
#  'At',
#  'Athens',
#  'Atlantic',
#  'Attention',
#  'Author',
#  'BUSINESS',
#  'BY',
#  'Bad',
#  'Baker',
#  'Baltimore',
#  'Barbary',
#  'Batavian',
#  'Beach',
#  'Because',
#  'Before',
#  'Being',
#  'Belief',
#  'Believing',
#  'Bell',
#  'Belleau',
#  'Beneath',
#  'Beneficent',
#  'Bernardin',
#  'Besides',
#  'Between',
#  'Beyond',
#  'Bible',
#  'Bicentennial',
#  'Bill',
#  'Blessed',
#  'Board',
#  'Bolivar',
#  'Boston',
#  'Both',
#  'Britain',
#  'Britannic',
#  'British',
#  'Brutus',
#  'Budapest',
#  'Bureau',
#  'Burger',
#  'Burma',
#  'Bush',
#  'Business',
#  'But',
#  'By',
#  'CONCLUSION',
#  'CONGRESS',
#  'COOPERATION',
#  'CRIMINAL',
#  'Cabinet',
#  'Caesar',
#  'California',
#  'Called',
#  'Calmness',
#  'Calvin',
#  'Camillus',
#  'Can',
#  'Canal',
#  'Cantons',
#  'Cape',
#  'Capital',
#  'Capitol',
#  'Cardinal',
#  'Care',
#  'Carolina',
#  'Carter',
#  'Cemetery',
#  'Central',
#  'Century',
#  'Certain',
#  'Chairman',
#  'Chamber',
#  'Change',
#  'Charta',
#  'Charter',
#  'Cheney',
#  'Chief',
#  'China',
#  'Chop',
#  'Chosen',
#  'Chosin',
#  'Christian',
#  'Christianity',
#  'Christians',
#  'Christmas',
#  'Christs',
#  'Church',
#  'Churchill',
#  'Cincinnati',
#  'Citizens',
#  'Civil',
#  'Civility',
#  'Claiming',
#  'Clay',
#  'Clearly',
#  'Clergy',
#  'Clinton',
#  'Closely',
#  'Coast',
#  'Cold',
#  'Coleman',
#  'Colonel',
#  'Columbia',
#  'Comfort',
#  'Commander',
#  'Commendable',
#  'Commerce',
#  'Commission',
#  'Commissioners',
#  'Common',
#  'Commons',
#  'Commonwealth',
#  'Communications',
#  'Communism',
#  'Communist',
#  'Communists',
#  'Compact',
#  'Compared',
#  'Conceived',
#  'Conceiving',
#  'Concord',
#  'Conditions',
#  'Confederacy',
#  'Confederation',
#  'Confidence',
#  'Confident',
#  'Confidently',
#  'Confusion',
#  'Congress',
#  'Congressional',
#  'Congressman',
#  'Connected',
#  'Conscious',
#  'Considering',
#  'Constantly',
#  'Constitution',
#  'Constitutional',
#  'Contemplating',
#  'Content',
#  'Continue',
#  'Convention',
#  'Convinced',
#  'Cook',
#  'Coolidge',
#  'Corporations',
#  'Cortes',
#  'Country',
#  'Countrymen',
#  'Courage',
#  'Court',
#  'Covenant',
#  'Creator',
#  'Crime',
#  'Croix',
#  'Cromwell',
#  'Cuba',
#  'Cuban',
#  'Cubans',
#  'Cures',
#  'Curtii',
#  'Dakota',
#  'Dakotas',
#  'Dangers',
#  'Dark',
#  'David',
#  'Day',
#  'December',
#  'Decii',
#  'Declaration',
#  'Deeply',
#  'Delano',
#  'Democracy',
#  'Democratic',
#  'Democrats',
#  'Department',
#  'Departments',
#  'Depression',
#  'Descending',
#  'Destructive',
#  'Did',
#  'Difficult',
#  'Dingley',
#  'Directly',
#  'Dirksen',
#  'Discord',
#  'Discouraging',
#  'Disease',
#  'Distinct',
#  'District',
#  'Distrust',
#  'Divided',
#  'Divine',
#  'Division',
#  'Do',
#  'Does',
#  'Doing',
#  'Dole',
#  'Domestic',
#  'Domingo',
#  'Dr',
#  'Dream',
#  'Due',
#  'Dulled',
#  'During',
#  'EDUCATION',
#  'EIGHTEENTH',
#  'ELECTION',
#  'ENFORCEMENT',
#  'Each',
#  'Earth',
#  'East',
#  'Economic',
#  'Economy',
#  'Egypt',
#  'Eight',
#  'Eisenhower',
#  'Elected',
#  'Emerson',
#  'Emperor',
#  'Employed',
#  'Encountering',
#  'Encouraging',
#  'Ending',
#  'Endowed',
#  'Engineers',
#  'England',
#  'English',
#  'Enough',
#  'Entering',
#  'Enterprises',
#  'Envy',
#  'Equal',
#  'Equality',
#  'Equally',
#  'Especially',
#  'Establishment',
#  'Europe',
#  'European',
#  'Eve',
#  'Even',
#  'Events',
#  'Eventually',
#  'Ever',
#  'Every',
#  'Everyone',
#  'Everywhere',
#  'Executive',
#  'Existing',
#  'Expenditure',
#  'Experience',
#  'Experiencing',
#  'FAILURE',
#  'FROM',
#  'Faced',
#  'Far',
#  'Farewell',
#  'Father',
#  'Fathers',
#  'February',
#  'Federal',
#  'Federalists',
#  'Fellow',
#  'Fifty',
#  'Finally',
#  'First',
#  'Florida',
#  'Floridas',
#  'Following',
#  'Fondly',
#  'For',
#  'Force',
#  'Forces',
#  'Foreign',
#  'Forge',
#  'Fort',
#  'Fortunate',
#  'Fortunately',
#  'Forty',
#  'Founders',
#  'Founding',
#  'Fountain',
#  'Four',
#  'Fourth',
#  'France',
#  'Franklin',
#  'Freed',
#  'Freedom',
#  'French',
#  'Friends',
#  'From',
#  'Front',
#  'Fruitful',
#  'Fully',
#  'G',
#  'GOVERNMENT',
#  'Gatun',
#  'Gaul',
#  'General',
#  'Genius',
#  'George',
#  'Germany',
#  'Gettysburg',
#  'Ghent',
#  'Gillis',
#  'Give',
#  'Giver',
#  'God',
#  'Godsend',
#  'Goethals',
#  'Golden',
#  'Good',
#  'Gore',
#  'Government',
#  'Governments',
#  'Grant',
#  'Grave',
#  'Great',
#  'Greater',
#  'Greatness',
#  'Greece',
#  'Gross',
#  'Growing',
#  'Guadalcanal',
#  'Guarantees',
#  'Guided',
#  'Gulf',
#  'HEALTH',
#  'Had',
#  'Hague',
#  'Half',
#  'Hall',
#  'Hand',
#  'Happily',
#  'Happiness',
#  'Happy',
#  'Hard',
#  'Has',
#  'Hatfield',
#  'Have',
#  'Having',
#  'He',
#  'Heads',
#  'Heaven',
#  'Heavenly',
#  'Help',
#  'Helvetic',
#  'Hemisphere',
#  'Hence',
#  'Here',
#  'Herein',
#  'High',
#  'Higher',
#  'Hill',
#  'Him',
#  'Hindus',
#  'His',
#  'History',
#  'Hitherto',
#  'Holy',
#  'Homes',
#  'Homestead',
#  'Honesty',
#  'Honorable',
#  'Honored',
#  'Honoring',
#  'Hope',
#  'Horn',
#  'House',
#  'Houses',
#  'How',
#  'However',
#  'Human',
#  'Humanity',
#  'Humphrey',
#  'Hundreds',
#  'I',
#  'II',
#  'INVESTIGATION',
#  'Idle',
#  'If',
#  'Ill',
#  'Illiteracy',
#  'Immunity',
#  'In',
#  'Inauguration',
#  'Inconsiderable',
#  'Indeed',
#  'Independence',
#  'Independently',
#  'Indian',
#  'Indians',
#  'Indies',
#  'Indo',
#  'Indulging',
#  'Industrial',
#  'Industry',
#  'Infinite',
#  'Information',
#  'Instead',
#  'Instinctively',
#  'Intelligence',
#  'Intentions',
#  'Internal',
#  'International',
#  'Internet',
#  'Interstate',
#  'Intrusted',
#  'Invasions',
#  'Investment',
#  'Invisible',
#  'Iowa',
#  'Iraq',
#  'Irritated',
#  'Is',
#  'Isaiah',
#  'Island',
#  'Islands',
#  'Isles',
#  'Israel',
#  'Isthmus',
#  'It',
#  'Italy',
#  'Its',
#  'Iwo',
#  'JUSTICE',
#  'Janeiro',
#  'January',
#  'Jealous',
#  'Jefferson',
#  'Jericho',
#  'Jews',
#  'Jima',
#  'John',
#  'Johnson',
#  'Joseph',
#  'Julia',
#  'July',
#  'Just',
#  'Justice',
#  'K',
#  'Kansas',
#  'Khe',
#  'Kindly',
#  'King',
#  'Knowing',
#  'Koran',
#  'Korea',
#  'Labor',
#  'Laboring',
#  'Lakes',
#  'Latent',
#  'Laws',
#  'Leader',
#  'League',
#  'Legislation',
#  'Legislature',
#  'Legitimate',
#  'Less',
#  'Let',
#  'Liberty',
#  'Like',
#  'Likewise',
#  'Limited',
#  'Lincoln',
#  'Lives',
#  'Loans',
#  'Local',
#  'Long',
#  'Look',
#  'Looking',
#  'Lord',
#  'Louisiana',
#  'Love',
#  'Loyalty',
#  'Luther',
#  'Lynchings',
#  'MANDATES',
#  'MY',
#  'MacLeish',
#  'Madison',
#  'Magistrate',
#  'Magna',
#  'Magnifying',
#  'Majesty',
#  'Majority',
#  'Make',
#  'Maker',
#  'Malaya',
#  'Mall',
#  'Manifestly',
#  'Mankind',
#  'Many',
#  'March',
#  'Mars',
#  'Martin',
#  'Massachusetts',
#  'Masses',
#  'Mathias',
#  'May',
#  'Mayflower',
#  'Meantime',
#  'Measures',
#  'Medicare',
#  'Mediterranean',
#  'Melancholy',
#  'Memorial',
#  'Men',
#  'Mental',
#  'Mexico',
#  'Micah',
#  'Michael',
#  'Middle',
#  'Mill',
#  'Mind',
#  'Mindful',
#  'Minorities',
#  'Mischievous',
#  'Misled',
#  'Miss',
#  'Mississippi',
#  'Missouri',
#  'Mitchell',
#  'Modern',
#  'Moment',
#  'Mondale',
#  'Monday',
#  'Monroe',
#  'Montana',
#  'Monticello',
#  'Moomaw',
#  'Moon',
#  'Moral',
#  'More',
#  'Moreover',
#  'Mormon',
#  'Moscow',
#  'Most',
#  'Mount',
#  'Mountains',
#  'Mr',
#  'Mrs',
#  'Much',
#  'Muslim',
#  'Muslims',
#  'Must',
#  'My',
#  'NATIONAL',
#  'Nation',
#  'National',
#  'Nations',
#  'Nature',
#  'Naval',
#  'Navy',
#  'Nearly',
#  'Nebraska',
#  'Negligence',
#  'Negro',
#  'Negroes',
#  'Neill',
#  'Neither',
#  'Never',
#  'New',
#  'Next',
#  'Nixon',
#  'No',
#  'None',
#  'Nor',
#  'Normandy',
#  'North',
#  'Northerners',
#  'Not',
#  'Nothing',
#  'Notwithstanding',
#  'November',
#  'Now',
#  'Nowhere',
#  'O',
#  'OF',
#  'OTHER',
#  'OUR',
#  'Occasionally',
#  'Ocean',
#  'Oceans',
#  'Octavius',
#  'October',
#  'Of',
#  'Off',
#  'Offices',
#  'Ohio',
#  'Old',
#  'Omaha',
#  'Omnipotence',
#  'On',
#  'Once',
#  'One',
#  'Only',
#  'Opportunism',
#  'Opportunity',
#  'Or',
#  'Order',
#  'Oregon',
#  'Orient',
#  'Orleans',
#  'Other',
#  'Others',
#  'Our',
#  'Ours',
#  'Out',
#  'Over',
#  'Overlooking',
#  'Overwhelmingly',
#  'PARTY',
#  'PEACE',
#  'PROGRESS',
#  'PUBLIC',
#  'Pacific',
#  'Page',
#  'Panama',
#  'Parchment',
#  'Parent',
#  'Parents',
#  'Paris',
#  'Parliament',
#  'Partial',
#  'Party',
#  'Passing',
#  'Passion',
#  'Patriotism',
#  'Patron',
#  'Peabody',
#  'Peace',
#  'Peking',
#  'Penetrating',
#  'Pennsylvania',
#  'People',
#  'Peoples',
#  'Perceiving',
#  'Perfection',
#  'Perhaps',
#  'Permanent',
#  'Perpetual',
#  'Perpetuity',
#  'Persian',
#  'Persistent',
#  'Personally',
#  'Petitions',
#  'Philippine',
#  'Philippines',
#  'Physically',
#  'Plainly',
#  'Pledge',
#  'Plenty',
#  'Political',
#  'Pool',
#  'Pork',
#  'Porto',
#  'Ports',
#  'Position',
#  'Possessing',
#  'Posterity',
#  'Potomac',
#  'Power',
#  'Powerful',
#  'Powers',
#  'Practices',
#  'Preeminently',
#  'Prejudice',
#  'Present',
#  'Presidency',
#  'President',
#  'Presidential',
#  'Presidents',
#  'Previous',
#  'Price',
#  'Prices',
#  'Primarily',
#  'Problems',
#  'Proceeding',
#  'Product',
#  'Profound',
#  'Progress',
#  'Proofs',
#  'Prophets',
#  'Prosperity',
#  'Protector',
#  'Providence',
#  'Province',
#  'Public',
#  'Purposes',
#  'Putting',
#  'Quayle',
#  'RELATION',
#  'RESPONSIBILITIES',
#  'Race',
#  'Rainbow',
#  'Raised',
#  'Rather',
#  'Reagan',
#  'Realizing',
#  'Reasoned',
#  'Recall',
#  'Recent',
#  'Recognition',
#  'Recognizing',
#  'Reconstruction',
#  'Red',
#  'Reflecting',
#  'Reform',
#  'Reforms',
#  'Relief',
#  'Relying',
#  'Removing',
#  'Renewed',
#  'Repeated',
#  'Representative',
#  'Representatives',
#  'Republic',
#  'Republican',
#  'Republicans',
#  'Republics',
#  'Reservoir',
#  'Resolved',
#  'Respecting',
#  'Resting',
#  'Restoration',
#  'Retrospect',
#  'Returning',
#  'Reverend',
#  'Revolution',
#  'Revolutionary',
#  'Rico',
#  'Rights',
#  'Rigid',
#  'Rio',
#  'River',
#  'Rocky',
#  'Roman',
#  'Rome',
#  'Roosevelt',
#  'Root',
#  'Rule',
#  'Ruler',
#  'Russia',
#  'SESSION',
#  'SPECIAL',
#  'SYSTEM',
#  'Sabine',
#  'Sacredly',
#  'Sahn',
#  'Salerno',
#  'Sanitary',
#  'Santo',
#  'Savior',
#  'Scandinavia',
#  'Science',
#  'Scientists',
#  'Scipios',
#  'Scripture',
#  'Scythia',
#  'Second',
#  'Secretary',
#  'Sectionalism',
#  'Security',
#  'Seeking',
#  'Self',
#  'Senate',
#  'Senator',
#  'Senators',
#  'September',
#  'Sermon',
#  'Service',
#  'Shall',
#  'She',
#  'Shortly',
#  'Should',
#  'Sinai',
#  'Since',
#  'Situated',
#  'Slowly',
#  'Small',
#  'So',
#  'Social',
#  'Societies',
#  'Society',
#  'Solemnly',
#  'Somalia',
#  'Some',
#  'Something',
#  'Sometimes',
#  'South',
#  'Southern',
#  'Sovereignty',
#  'Soviet',
#  'Soviets',
#  'Spain',
#  'Spanish',
#  'Speaker',
#  'Splendid',
#  'St',
#  'Stages',
#  'Standing',
#  'Stars',
#  'Start',
#  'Starting',
#  'State',
#  'States',
#  'Steadfast',
#  'Stennis',
#  'Steps',
#  'Still',
#  'Stripped',
#  'Strong',
#  'Subordinate',
#  'Such',
#  'Suicide',
#  'Suitably',
#  'Sumter',
#  'Superficial',
#  'Suppose',
#  'Supreme',
#  'Surely',
#  'THE',
#  ...]

# %%
text4.count("democracy")
# Out:
# 52

# %% [markdown]
# *look at the overall frequency of words*

# %%
myFreqDist = FreqDist(text4)

# %%
myFreqDist.most_common(100)
# Out:
# [('the', 9281),
#  ('of', 6970),
#  (',', 6840),
#  ('and', 4991),
#  ('.', 4676),
#  ('to', 4311),
#  ('in', 2527),
#  ('a', 2134),
#  ('our', 1905),
#  ('that', 1688),
#  ('be', 1460),
#  ('is', 1403),
#  ('we', 1141),
#  ('for', 1075),
#  ('by', 1036),
#  ('it', 1011),
#  ('which', 1002),
#  ('have', 994),
#  ('not', 916),
#  ('as', 888),
#  ('with', 886),
#  ('will', 846),
#  ('I', 831),
#  ('are', 774),
#  ('all', 758),
#  ('their', 719),
#  ('this', 700),
#  ('The', 619),
#  ('has', 611),
#  ('people', 559),
#  ('its', 554),
#  (';', 544),
#  ('or', 537),
#  ('from', 521),
#  ('on', 496),
#  ('We', 483),
#  ('been', 482),
#  ('but', 479),
#  ('can', 457),
#  ('us', 455),
#  ('my', 449),
#  ('no', 406),
#  ('an', 377),
#  ('--', 363),
#  ('upon', 363),
#  ('who', 356),
#  ('It', 356),
#  ('so', 354),
#  ('must', 345),
#  ('they', 341),
#  ('Government', 331),
#  ('them', 327),
#  ('States', 325),
#  ('should', 318),
#  ('may', 316),
#  ('at', 316),
#  ('great', 312),
#  ('world', 312),
#  ('shall', 310),
#  ('more', 302),
#  ('country', 296),
#  ('those', 296),
#  ('-', 280),
#  ('every', 272),
#  ('any', 269),
#  ('was', 268),
#  ('government', 260),
#  ('other', 253),
#  ('own', 245),
#  ('peace', 244),
#  ('nation', 235),
#  ('than', 234),
#  ('only', 231),
#  ('citizens', 230),
#  ('new', 227),
#  ('one', 226),
#  ('power', 226),
#  ('In', 222),
#  ('public', 222),
#  ('do', 220),
#  ('these', 218),
#  ("'", 214),
#  ('would', 209),
#  ('time', 204),
#  ('s', 202),
#  ('Constitution', 196),
#  ('such', 192),
#  ('America', 192),
#  ('now', 190),
#  ('me', 186),
#  ('if', 184),
#  ('nations', 181),
#  ('free', 179),
#  ('freedom', 174),
#  ('under', 173),
#  ('his', 171),
#  ('there', 169),
#  ('most', 166),
#  ('United', 165),
#  ('when', 162)]

# %% [markdown]
# *remove commonly used words*

# %%
from nltk.corpus import stopwords # Import the stop word list
print (stopwords.words("english"))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'couldn', 'didn', 'doesn', 'hadn', 'hasn', 'haven', 'isn', 'ma', 'mightn', 'mustn', 'needn', 'shan', 'shouldn', 'wasn', 'weren', 'won', 'wouldn']

# %%
reducedWords = [w for w in text4 if not w in stopwords.words("english")]
print (reducedWords)
# Out:
# ['Fellow', '-', 'Citizens', 'Senate', 'House', 'Representatives', ':', 'Among', 'vicissitudes', 'incident', 'life', 'event', 'could', 'filled', 'greater', 'anxieties', 'notification', 'transmitted', 'order', ',', 'received', '14th', 'day', 'present', 'month', '.', 'On', 'one', 'hand', ',', 'I', 'summoned', 'Country', ',', 'whose', 'voice', 'I', 'never', 'hear', 'veneration', 'love', ',', 'retreat', 'I', 'chosen', 'fondest', 'predilection', ',', ',', 'flattering', 'hopes', ',', 'immutable', 'decision', ',', 'asylum', 'declining', 'years', '--', 'retreat', 'rendered', 'every', 'day', 'necessary', 'well', 'dear', 'addition', 'habit', 'inclination', ',', 'frequent', 'interruptions', 'health', 'gradual', 'waste', 'committed', 'time', '.', 'On', 'hand', ',', 'magnitude', 'difficulty', 'trust', 'voice', 'country', 'called', ',', 'sufficient', 'awaken', 'wisest', 'experienced', 'citizens', 'distrustful', 'scrutiny', 'qualifications', ',', 'could', 'overwhelm', 'despondence', 'one', '(', 'inheriting', 'inferior', 'endowments', 'nature', 'unpracticed', 'duties', 'civil', 'administration', ')', 'ought', 'peculiarly', 'conscious', 'deficiencies', '.', 'In', 'conflict', 'emotions', 'I', 'dare', 'aver', 'faithful', 'study', 'collect', 'duty', 'appreciation', 'every', 'circumstance', 'might', 'affected', '.', 'All', 'I', 'dare', 'hope', ',', 'executing', 'task', ',', 'I', 'much', 'swayed', 'grateful', 'remembrance', 'former', 'instances', ',', 'affectionate', 'sensibility', 'transcendent', 'proof', 'confidence', 'fellow', 'citizens', ',', 'thence', 'little', 'consulted', 'incapacity', 'well', 'disinclination', 'weighty', 'untried', 'cares', ',', 'error', 'palliated', 'motives', 'mislead', ',', 'consequences', 'judged', 'country', 'share', 'partiality', 'originated', '.', 'Such', 'impressions', 'I', ',', 'obedience', 'public', 'summons', ',', 'repaired', 'present', 'station', ',', 'would', 'peculiarly', 'improper', 'omit', 'first', 'official', 'act', 'fervent', 'supplications', 'Almighty', 'Being', 'rules', 'universe', ',', 'presides', 'councils', 'nations', ',', 'whose', 'providential', 'aids', 'supply', 'every', 'human', 'defect', ',', 'His', 'benediction', 'may', 'consecrate', 'liberties', 'happiness', 'people', 'United', 'States', 'Government', 'instituted', 'essential', 'purposes', ',', 'may', 'enable', 'every', 'instrument', 'employed', 'administration', 'execute', 'success', 'functions', 'allotted', 'charge', '.', 'In', 'tendering', 'homage', 'Great', 'Author', 'every', 'public', 'private', 'good', ',', 'I', 'assure', 'expresses', 'sentiments', 'less', ',', 'fellow', 'citizens', 'large', 'less', 'either', '.', 'No', 'people', 'bound', 'acknowledge', 'adore', 'Invisible', 'Hand', 'conducts', 'affairs', 'men', 'United', 'States', '.', 'Every', 'step', 'advanced', 'character', 'independent', 'nation', 'seems', 'distinguished', 'token', 'providential', 'agency', ';', 'important', 'revolution', 'accomplished', 'system', 'united', 'government', 'tranquil', 'deliberations', 'voluntary', 'consent', 'many', 'distinct', 'communities', 'event', 'resulted', 'compared', 'means', 'governments', 'established', 'without', 'return', 'pious', 'gratitude', ',', 'along', 'humble', 'anticipation', 'future', 'blessings', 'past', 'seem', 'presage', '.', 'These', 'reflections', ',', 'arising', 'present', 'crisis', ',', 'forced', 'strongly', 'mind', 'suppressed', '.', 'You', 'join', ',', 'I', 'trust', ',', 'thinking', 'none', 'influence', 'proceedings', 'new', 'free', 'government', 'auspiciously', 'commence', '.', 'By', 'article', 'establishing', 'executive', 'department', 'made', 'duty', 'President', '"', 'recommend', 'consideration', 'measures', 'shall', 'judge', 'necessary', 'expedient', '."', 'The', 'circumstances', 'I', 'meet', 'acquit', 'entering', 'subject', 'refer', 'great', 'constitutional', 'charter', 'assembled', ',', ',', 'defining', 'powers', ',', 'designates', 'objects', 'attention', 'given', '.', 'It', 'consistent', 'circumstances', ',', 'far',  ...

# %%
myFreqDistReduced = FreqDist(reducedWords)

# %%
myFreqDistReduced.most_common(10);

# %% [markdown]
# *find long words*

# %%
long_words = [w for w in myFreqDistReduced if len(w) > 15]

# %%
print(long_words);
# Out:
# ['antiphilosophists', 'constitutionally', 'discountenancing', 'misrepresentation', 'contradistinction', 'misunderstanding', 'responsibilities', 'unconstitutional', 'uncharitableness', 'instrumentalities', 'disqualification', 'misappropriation', 'transcontinental', 'sentimentalizing', 'internationality', 'RESPONSIBILITIES', 'irresponsibility', 'enthusiastically']

# %% [markdown]
# *eliminate numbers and punctuation*

# %%
myWordList = [w for w in reducedWords if re.search("[a-zA-Z]", w)]

# %%
myFreqDistReduced = FreqDist(myWordList)

# %%
myFreqDistReduced.most_common(10);

# %% [markdown]
# *more searching*

# %%
text4.findall(r"<a> (<.*>) <world>")
# Out:
# troubled; stricken; new; new; watching; troubled; whole; new

# %%
text4.findall(r"<.*> <.*> <world>");
# Out:
# of the world; and the world; all the world; of the world; a troubled
# world; the ancient world; , the world; to the world; the whole world;
# of the world; in the world; to the world; the civilized world; of the
# world; all the world; before the world; in the world; of the world;
# much the world; to the world; throughout the world; all the world; .
# The world; . The world; throughout the world; of the world; the
# civilized world; as the world; throughout the world; of the world; in
# the world; unto the world; in the world; the civilized world;
# preparing the world; with the world; of the world; to the world; for
# the world; of the world; of the world; the civilized world; to the
# world; of the world; throughout the world; of the world; of the world;
# to the world; in the world; with the world; of the world; of the
# world; throughout the world; to the world; of the world; of the world;
# in the world; of the world; the whole world; the whole world; of the
# world; of the world; throughout the world; of the world; surveys the
# world; seen a world; new - world; seen the world; in the world; will
# the world; of the world; views of world; establish a world; , a world;
# in the world; by the world; for the world; of the world; needs a
# world; new - world; While the world; The business world; to the world;
# in the world; of the world; invite the world; . The world; . The
# world; leading the world; all the world; all the world; in the world;
# in the world; in the world; in the world; of the world; in the world;
# of the world; of the world; of the world; in the world; The whole
# world; haunt the world; with the world; throughout the world; to the
# world; upon the world; of the world; around the world; to restore
# world; field of world; with a world; the modern world; , of world; a
# stricken world; morally better world; of the world; an alien world; of
# the world; an anguished world; of the world; for the world; to the
# world; , a world; that the world; bring about world; to the world;
# expansion of world; of the world; over the world; the free world;
# programs for world; venture in world; barriers to world; on increased
# world; of the world; of the world; of the world; of the world; weaving
# a world; of the world; toward a world; in a world; : The world; of the
# world; in the world; of the world; all the world; in the world; the
# free world; difference between world; friends the world; labor for
# world; in our world; in the world; the free world; in the world; bonds
# the world; in the world; of our world; For our world; the free world;
# all the world; in the world; Yet the world; in a world; justice the
# world; , the world; in the world; in the world; fear this world; this
# divided world; this divided world; the wide world; . The world; around
# the world; To that world; a new world; of the world; light the world;
# of the world; of the world; that the world; in a world; of our world;
# There is world; Is our world; a new world; and the world; of the
# world; of the world; of the world; kind of world; lead the world; make
# the world; an open world; -- a world; of the world; of the world;
# divide the world; of the world; of the world; in the world; of the
# world; in the world; in the world; in the world; preserving the world;
# of the world; divided the world; of the world; in the world; to the
# world; in the world; in the world; of the world; in the world; what
# the world; all the world; . The world; and peaceful world; that a
# world; . The world; limit the world; of the world; in the world; a
# watching world; and the world; then the world; of the world;
# throughout the world; of the world; ' s world; around the world;
# lighted the world; in the world; a troubled world; throughout the
# world; start the world; leave this world; in the world; rid the world;
# in the world; is the world; victory for world; leading the world; to a
# world; in a world; fill the world; and hopeful world; in the world;
# and a world; of the world; of the world; of the world; of the world;
# before the world; To the world; around the world; show the world; in
# the world; to the world; in a world; still the world; around the
# world; remaking our world; This new world; of the world; in a world;
# is the world; , the world; . The world; , the world; , the world; ,
# the world; the new world; lead the world; this new world; Across the
# world; onto the world; became the world; saved the world; in two
# world; as the world; in the world; around the world; . The world;
# people the world; in the world; And the world; a whole world;
# fortifies the world; all the world; all the world; a new world; into
# the world; in the world; of the world; in our world; all the world; in
# our world; of the world; of our world; In a world; all the world;
# light the world; as the world; the Muslim world; consume the world;
# For the world; and the world; the future world

# %%
text4.findall(r"<world> <.*> <.*> ");
# Out:
# world . I; world , which; world ; if; world of virtuous; world .
# During; world , during; world ' s; world that an; world should
# witness; world is indeed; world , the; world our inherent; world .
# Our; world , and; world , but; world . Let; world . Abroad; world .
# This; world may have; world , must; world . Mind; world . To; world
# has nothing; world beholds the; world from that; world . Should; world
# . An; world has never; world . Next; world has rapidly; world ? In;
# world because of; world , and; world is tending; world , in; world '
# s; world . Fellow; world the first; world did not; world . The; world
# ' s; world , shall; world ' s; world . Until; world , and; world which
# ,; world , and; world the glorious; world , an; world , and; world .
# The; world are important; world will rock; world as it; world , and;
# world armed and; world have noble; world , violates; world . They;
# world for stage; world . There; world and in; world . In; world and
# in; world about him; world passion spend; world Republic .; world
# rivet its; world , with; world misconstrue .; world , great; world
# opinion ;; world court for; world supergovernment is; world and a;
# world . The; world is well; world , we; world - wide; world democracy
# ,; world ' s; world reflects the; world , maintain; world ' s; world .
# We; world to the; world has witnessed; world upheaval has; world in
# the; world , and; world may see; world . It; world , actively; world .
# Some; world is to; world . While; world . It; world . What; world .
# Through; world . We; world , but; world is at; world . No; world ,
# but; world . We; world . But; world , the; world . Fortunately; world
# , there; world trade by; world policy I; world of neighbors; world has
# produced; world relations .; world may require; world . This; world .
# And; world , lived; world , members; world . So; world . In; world .
# It; world the essential; world in which; world is so; world recovery
# and; world . We; world trade on; world . Our; world now agree; world .
# In; world economic recovery; world recovery .; world trade and; world
# trade .; world are living; world , through; world ' s; world into
# triumphant; world fabric of; world in a; world where man; world of
# justice; world and we; world to our; world , we; world . And; world .
# This; world for the; world ' s; world leadership and; world over to;
# world peace ,; world , we; world , we; world ' s; world means danger;
# world over .; world must first; world . For; world is where; world '
# s; world . The; world , especially; world of International; world
# where moral; world can know; world promises only; world a people;
# world ' s; world of change; world than in; world . Thus; world of our;
# world is very; world . Let; world assembly of; world of law; world ,
# only; world . And; world : ask; world , ask; world will not; world
# where change; world as it; world enough for; world gone ?; world
# coming ?; world , I; world community :; world want peace; world are
# afraid; world we will; world at last; world safe for; world -- open;
# world in which; world . I; world , and; world . I; world . I; world as
# God; world . The; world . Because; world . The; world is not; world .
# But; world ' s; world , let; world for too; world can be; world in
# which; world . As; world . At; world ' s; world . Let; world what the;
# world has not; world . Let; world itself is; world that is; world
# which others; world is still; world ' s; world might say; world ,
# this; world that we; world . So; world beyond .; world ' s; world .
# We; world , is; world do not; world on Guadalcanal; world with our;
# world there was; world ; when; world , and; world over again; world a
# better; world who scorn; world of the; world has grown; world ' s;
# world peace .; world to a; world rich in; world that is; world with
# our; world . God; world , nor; world refreshed by; world are moving;
# world move toward; world agitate for; world . My; world united ,;
# world , too; world strong ,; world , we; world ' s; world , and; world
# warmed by; world ' s; world . Communications; world , and; world has
# already; world but the; world in which; world to come; world for whom;
# world economy ,; world environment ,; world AIDS crisis; world arms
# race; world is more; world we did; world . Together; world , we; world
# stage to; world ' s; world from tyranny; world wars and; world ' s;
# world , and; world . These; world is no; world over .; world ,
# igniting; world ' s; world of democracies; world ' s; world ' s; world
# . From; world that became; world to protect; world by history; world
# simmer in; world is the; world . America; world . This; world : All;
# world . A; world moving toward; world , and; world , and; world grows
# smaller; world , we; world ' s; world has changed; world , duties;
# world ... that

# %%
text4.concordance("world");
# Out:
# Displaying 25 of 329 matches:
# izens and command the respect of the world . I dwell on this prospect with ever
# py fruits of them to himself and the world , which are daily increasing , and t
# dship , and benevolence with all the world ; if an unshaken confidence in the h
# and the Protector in all ages of the world of virtuous liberty , continue His b
# e conflicting elements of a troubled world . During the contest of opinion thro
# hroes and convulsions of the ancient world , during the agonizing spasms of inf
# nary fear that this Government , the world ' s best hope , may by possibility w
# on . Nor was it uninteresting to the world that an experiment should be fairly
# hich it would be unwilling the whole world should witness , can be written down
# anced . The present situation of the world is indeed without a parallel and tha
# rtiality . If there be candor in the world , the truth of these assertions will
# ts of our naval heroes proved to the world our inherent capacity to maintain ou
# iration and respect of the civilized world . Our physical attainments have not
# any government ever known to the Old World , with an utter incapacity to oppres
# eventful period in the annals of the world , and through all the vicissitudes o
# e are not only at peace with all the world , but have few causes of controversy
# ttitude in which we stand before the world . Let us exercise forbearance and fi
# e we stand without a parallel in the world . Abroad we enjoy the respect and ,
# munity with the other nations of the world . This provident forecast has been v
# ade in the former . However much the world may have improved in many respects i
# not only to our country , but to the world , must be deprecated by every patrio
#  aegis , and multitudes from the Old World are flocking to our shores to partic
# rcourse have extended throughout the world . Mind , no longer tasked in devisin
# is peace with each other and all the world . To enlarge its limits is to extend
# tories and increasing millions . The world has nothing to fear from military am

# %%
text4.similar("world")
# Out:
# people government nation union country constitution states future time
# executive law land laws spirit congress earth south century past way

# %%
# %matplotlib inline

# %%
text4.dispersion_plot(["world", "democracy", "freedom", "duties", "America"]);

# %%
text1.dispersion_plot(["whale", "coast", "sea", "shore", "angry"])

# %%
text4.dispersion_plot(["terror", "fear", "Isis", "Iraq", "depression", "Britain"])

# %%
text4.dispersion_plot(["freedom", "responsibility", "justice"])

# %%
def graph(myFile):
  f = open(myFile, "r")
  inputfile = f.read()
  tokens = nltk.tokenize.word_tokenize(inputfile)
  fd = nltk.FreqDist(tokens)
  fd.plot(30,cumulative=False)

# %%
myFile = nltk.data.find('corpora/gutenberg/melville-moby_dick.txt')

# %%
graph(myFile)
